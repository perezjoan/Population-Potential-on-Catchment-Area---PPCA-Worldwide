# %%
'''
PPCA 5.0 RESIDENTIAL & NON-RESIDENTIAL BUILDINGS : FILL NULL VALUES WITH MACHINE LEARNING

Author : Perez, Joan

XXX

Requirements:
- A specific working environment (see README on the github page of the project https://github.com/perezjoan/PPCA-codes?tab=readme-ov-file)
- Output file from PPCA 4.0 ('osm_all_buildings_res_type_with_null' (Polygon), OSM all buildings)

Guide to run the script:
- Fill 0.2 box

Output :
- A geopackage file with a single layer
    * 'osm_all_buildings_res_type_with_null' (Polygon), osm buildings with residential classification

Acknowledgement: This resource was produced within the emc2 project, which is funded by ANR (France), FFG (Austria), MUR (Italy) and 
Vinnova (Sweden) under the Driving Urban Transition Partnership, which has been co-funded by the European Commission.

License: Attribution-ShareAlike 4.0 International - CC-BY-SA-4.0 license
'''

# %%
# 0.1 : libraries
import pandas as pd
import numpy as np
import geopandas as gpd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# 0.2 : Box to fil with informations

# Name of the case study
Name = 'Nice'

# %%
# 1. DATA PREPARATION & SUBSET DATA INTO TRAIN AND TEST DATA 0.7 / 0.3

gpkg = f'PPCA4_{Name}.gpkg'
building = gpd.read_file(gpkg, layer='osm_all_buildings_res_type_with_null')

# List of columns to keep
columns_to_keep = ['FL', 'A', 'P', 'E', 'C', 'FA', 'ECA', 'EA', 'SW', 'type']

# Subset the DataFrame
building_filtered = building[columns_to_keep]

# Subset the data where 'type' is 1 or 2
building_res = building_filtered[building_filtered['type'].isin([1, 2])]

# Subset the data where 'type' is 0
building_null = building_filtered[building_filtered['type'] == 0]

# Set a random seed for reproducibility
np.random.seed(45)

# Create a boolean mask for selecting 70% of the data for training
mask = np.random.rand(len(building_res)) < 0.7

# Split the data into training and testing sets
data_train = building_res[mask]
data_test = building_res[~mask]

# Display the shapes of the resulting datasets
print(f"Training data shape: {data_train.shape}")
print(f"Testing data shape: {data_test.shape}")
# Out:
# Training data shape: (8233, 10)
# Testing data shape: (3518, 10)

# %%
# 2. CALCULATE DECISION TREE CLASSIFIER & PRINT PRECISION

# Initialize the Decision Tree Classifier
np.random.seed(45)
clf = DecisionTreeClassifier()

# Separate the target variable and features for the training set
X_train = data_train.drop(columns=['type'])
y_train = data_train['type']

# Train the classifier
clf.fit(X_train, y_train)

# Separate the features and target variable for the test set
X_test = data_test.drop(columns=['type'])
y_test = data_test['type']

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test data: {accuracy:.2f}")

# Apply the model to building_null
# Ensure that we are using the same features as those used during training
X_null = building_null.drop(columns=['type'])

# Make sure there are no additional columns
X_null = X_null[X_train.columns]

# Predict the types for building_null
building_null.loc[:, 'type'] = clf.predict(X_null)
# Out:
# Accuracy on test data: 0.77

# %%
# 3. APPLY THE TREE TO THE NULL VALUES
X_null = building_filtered.drop(columns=['type'])

# Predict the types for building_null
building_filtered = building_filtered.copy()  # Ensure we are working on a copy
building_filtered.loc[:, 'type_pred'] = clf.predict(X_null)

# Keep only one column from building_filtered
type_pred = building_filtered[['type_pred']]

# Concatenate along columns
building_final = pd.concat([building.reset_index(drop=True), type_pred.reset_index(drop=True)], axis=1)

# Create the 'type_filled' column which take the non null values of building type, otherwise fill the null values with the model predictions
building_final['type_filled'] = np.where(building_final['type'].isin([1, 2]), 
                                         building_final['type'], 
                                         building_final['type_pred'])

# %%
# Define custom colors
colors = ['green', 'red']

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))
building_final.plot(column='type_filled', legend=True, ax=ax, cmap=ListedColormap(colors))

# Add a title
plt.title('Distribution of Building Types')

# Show the plot
plt.show()

# %%
# A1. TREE VISUALIZATION
# Print the decision tree
text_representation = tree.export_text(clf, feature_names=list(X_train.columns))
print(text_representation)

# Optionally, visualize the decision tree (requires matplotlib)
fig = plt.figure(figsize=(25, 20))
_ = tree.plot_tree(clf, 
                   feature_names=X_train.columns,  
                   class_names=['0', '1'],
                   filled=True)
plt.show()
# Out:
# |--- FL <= 1.50
# |   |--- A <= 49.71
# |   |   |--- FA <= 31.97
# |   |   |   |--- SW <= 0.27
# |   |   |   |   |--- A <= 41.32
# |   |   |   |   |   |--- FA <= 21.64
# |   |   |   |   |   |   |--- E <= 0.44
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- E >  0.44
# |   |   |   |   |   |   |   |--- P <= 23.29
# |   |   |   |   |   |   |   |   |--- E <= 0.72
# |   |   |   |   |   |   |   |   |   |--- P <= 17.69
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 6.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  6.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- P >  17.69
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 20.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  20.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- E >  0.72
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  23.29
# |   |   |   |   |   |   |   |   |--- ECA <= 4.93
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  4.93
# |   |   |   |   |   |   |   |   |   |--- P <= 24.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- P >  24.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FA >  21.64
# |   |   |   |   |   |   |--- C <= 0.96
# |   |   |   |   |   |   |   |--- C <= 0.95
# |   |   |   |   |   |   |   |   |--- ECA <= 17.14
# |   |   |   |   |   |   |   |   |   |--- A <= 23.70
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- A >  23.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  17.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- C >  0.95
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- C >  0.96
# |   |   |   |   |   |   |   |--- P <= 19.74
# |   |   |   |   |   |   |   |   |--- EA <= 6.17
# |   |   |   |   |   |   |   |   |   |--- EA <= 6.15
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- EA >  6.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- EA >  6.17
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  19.74
# |   |   |   |   |   |   |   |   |--- P <= 19.75
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  19.75
# |   |   |   |   |   |   |   |   |   |--- A <= 26.05
# |   |   |   |   |   |   |   |   |   |   |--- A <= 25.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- A >  25.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  26.05
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |--- A >  41.32
# |   |   |   |   |   |--- P <= 28.86
# |   |   |   |   |   |   |--- P <= 26.54
# |   |   |   |   |   |   |   |--- A <= 42.01
# |   |   |   |   |   |   |   |   |--- P <= 26.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  26.19
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  42.01
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- P >  26.54
# |   |   |   |   |   |   |   |--- P <= 27.02
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- P >  27.02
# |   |   |   |   |   |   |   |   |--- P <= 28.65
# |   |   |   |   |   |   |   |   |   |--- A <= 42.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  42.85
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 4.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  4.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- P >  28.65
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- P >  28.86
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- SW >  0.27
# |   |   |   |   |--- C <= 0.54
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.54
# |   |   |   |   |   |--- SW <= 0.27
# |   |   |   |   |   |   |--- FA <= 11.79
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FA >  11.79
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- SW >  0.27
# |   |   |   |   |   |   |--- A <= 24.02
# |   |   |   |   |   |   |   |--- A <= 21.29
# |   |   |   |   |   |   |   |   |--- FA <= 17.91
# |   |   |   |   |   |   |   |   |   |--- FA <= 7.82
# |   |   |   |   |   |   |   |   |   |   |--- A <= 18.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- A >  18.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FA >  7.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  17.91
# |   |   |   |   |   |   |   |   |   |--- P <= 18.51
# |   |   |   |   |   |   |   |   |   |   |--- P <= 18.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- P >  18.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- P >  18.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  21.29
# |   |   |   |   |   |   |   |   |--- ECA <= 6.03
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ECA >  6.03
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.60
# |   |   |   |   |   |   |   |   |   |   |--- A <= 21.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- A >  21.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- SW >  0.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- A >  24.02
# |   |   |   |   |   |   |   |--- ECA <= 16.66
# |   |   |   |   |   |   |   |   |--- SW <= 0.71
# |   |   |   |   |   |   |   |   |   |--- ECA <= 9.94
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 9.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  9.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ECA >  9.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- SW >  0.71
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- ECA >  16.66
# |   |   |   |   |   |   |   |   |--- ECA <= 17.11
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ECA >  17.11
# |   |   |   |   |   |   |   |   |   |--- E <= 0.60
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- E >  0.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- FA >  31.97
# |   |   |   |--- C <= 0.91
# |   |   |   |   |--- class: 1
# |   |   |   |--- C >  0.91
# |   |   |   |   |--- SW <= 0.29
# |   |   |   |   |   |--- P <= 28.15
# |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |--- E <= 0.45
# |   |   |   |   |   |   |   |   |--- E <= 0.41
# |   |   |   |   |   |   |   |   |   |--- A <= 38.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- A >  38.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- E >  0.41
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- E >  0.45
# |   |   |   |   |   |   |   |   |--- A <= 32.27
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- A >  32.27
# |   |   |   |   |   |   |   |   |   |--- EA <= 8.43
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- EA >  8.43
# |   |   |   |   |   |   |   |   |   |   |--- P <= 27.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- P >  27.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- P >  28.15
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- SW >  0.29
# |   |   |   |   |   |--- E <= 0.48
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- E >  0.48
# |   |   |   |   |   |   |--- ECA <= 12.45
# |   |   |   |   |   |   |   |--- SW <= 0.40
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- SW >  0.40
# |   |   |   |   |   |   |   |   |--- A <= 39.51
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- A >  39.51
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- SW >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ECA >  12.45
# |   |   |   |   |   |   |   |--- EA <= 18.38
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- EA >  18.38
# |   |   |   |   |   |   |   |   |--- EA <= 21.05
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- EA >  21.05
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |--- A >  49.71
# |   |   |--- ECA <= 124.19
# |   |   |   |--- E <= 0.36
# |   |   |   |   |--- E <= 0.25
# |   |   |   |   |   |--- FL <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FL >  0.50
# |   |   |   |   |   |   |--- A <= 203.81
# |   |   |   |   |   |   |   |--- SW <= 0.72
# |   |   |   |   |   |   |   |   |--- E <= 0.24
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- E >  0.24
# |   |   |   |   |   |   |   |   |   |--- E <= 0.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- E >  0.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- SW >  0.72
# |   |   |   |   |   |   |   |   |--- SW <= 0.87
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SW >  0.87
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- A >  203.81
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- E >  0.25
# |   |   |   |   |   |--- SW <= 0.03
# |   |   |   |   |   |   |--- C <= 0.99
# |   |   |   |   |   |   |   |--- P <= 79.54
# |   |   |   |   |   |   |   |   |--- E <= 0.29
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- E >  0.29
# |   |   |   |   |   |   |   |   |   |--- EA <= 65.03
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 63.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  63.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- EA >  65.03
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- P >  79.54
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- C >  0.99
# |   |   |   |   |   |   |   |--- ECA <= 95.32
# |   |   |   |   |   |   |   |   |--- FA <= 83.98
# |   |   |   |   |   |   |   |   |   |--- FA <= 63.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FA >  63.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  83.98
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- ECA >  95.32
# |   |   |   |   |   |   |   |   |--- A <= 159.26
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- A >  159.26
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- SW >  0.03
# |   |   |   |   |   |   |--- A <= 67.15
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- A >  67.15
# |   |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |   |--- C <= 0.69
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.69
# |   |   |   |   |   |   |   |   |   |--- FA <= 129.92
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FA >  129.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |   |--- FA <= 96.75
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FA >  96.75
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.39
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- SW >  0.39
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- E >  0.36
# |   |   |   |   |--- SW <= 0.14
# |   |   |   |   |   |--- C <= 0.96
# |   |   |   |   |   |   |--- A <= 541.35
# |   |   |   |   |   |   |   |--- A <= 84.33
# |   |   |   |   |   |   |   |   |--- EA <= 35.05
# |   |   |   |   |   |   |   |   |   |--- P <= 32.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- P >  32.35
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- EA >  35.05
# |   |   |   |   |   |   |   |   |   |--- EA <= 46.32
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- EA >  46.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- A >  84.33
# |   |   |   |   |   |   |   |   |--- A <= 274.85
# |   |   |   |   |   |   |   |   |   |--- FA <= 184.15
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- FA >  184.15
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 145.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  145.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- A >  274.85
# |   |   |   |   |   |   |   |   |   |--- A <= 287.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- A >  287.31
# |   |   |   |   |   |   |   |   |   |   |--- P <= 91.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- P >  91.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- A >  541.35
# |   |   |   |   |   |   |   |--- P <= 229.91
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  229.91
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- C >  0.96
# |   |   |   |   |   |   |--- A <= 242.15
# |   |   |   |   |   |   |   |--- FA <= 219.15
# |   |   |   |   |   |   |   |   |--- ECA <= 67.15
# |   |   |   |   |   |   |   |   |   |--- C <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- A <= 84.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- A >  84.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- C >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 57.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  57.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  67.15
# |   |   |   |   |   |   |   |   |   |--- P <= 50.51
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 73.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  73.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- P >  50.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FA >  219.15
# |   |   |   |   |   |   |   |   |--- E <= 0.53
# |   |   |   |   |   |   |   |   |   |--- A <= 86.83
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- A >  86.83
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- E >  0.53
# |   |   |   |   |   |   |   |   |   |--- P <= 51.06
# |   |   |   |   |   |   |   |   |   |   |--- A <= 68.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- A >  68.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- P >  51.06
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 52.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  52.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- A >  242.15
# |   |   |   |   |   |   |   |--- EA <= 122.82
# |   |   |   |   |   |   |   |   |--- P <= 64.49
# |   |   |   |   |   |   |   |   |   |--- A <= 252.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- A >  252.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  64.49
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- EA >  122.82
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- SW >  0.14
# |   |   |   |   |   |--- A <= 312.25
# |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |--- FA <= 54.77
# |   |   |   |   |   |   |   |   |--- SW <= 0.37
# |   |   |   |   |   |   |   |   |   |--- A <= 170.86
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 30.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- EA >  30.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- A >  170.86
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- SW >  0.37
# |   |   |   |   |   |   |   |   |   |--- C <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- FA >  54.77
# |   |   |   |   |   |   |   |   |--- P <= 92.34
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 31.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- EA >  31.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- SW >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- P >  92.34
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |--- SW <= 0.61
# |   |   |   |   |   |   |   |   |--- E <= 0.50
# |   |   |   |   |   |   |   |   |   |--- P <= 32.67
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 30.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  30.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- P >  32.67
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 90.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  90.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- E >  0.50
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- SW >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- SW >  0.61
# |   |   |   |   |   |   |   |   |--- E <= 0.78
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- E >  0.78
# |   |   |   |   |   |   |   |   |   |--- A <= 143.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- A >  143.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- A >  312.25
# |   |   |   |   |   |   |--- EA <= 131.44
# |   |   |   |   |   |   |   |--- E <= 0.94
# |   |   |   |   |   |   |   |   |--- C <= 0.87
# |   |   |   |   |   |   |   |   |   |--- ECA <= 55.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ECA >  55.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.87
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- E >  0.94
# |   |   |   |   |   |   |   |   |--- P <= 130.66
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- P >  130.66
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- EA >  131.44
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- ECA >  124.19
# |   |   |   |--- C <= 0.98
# |   |   |   |   |--- A <= 891.74
# |   |   |   |   |   |--- P <= 75.07
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- P >  75.07
# |   |   |   |   |   |   |--- C <= 0.92
# |   |   |   |   |   |   |   |--- E <= 0.19
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- E >  0.19
# |   |   |   |   |   |   |   |   |--- ECA <= 312.40
# |   |   |   |   |   |   |   |   |   |--- A <= 731.10
# |   |   |   |   |   |   |   |   |   |   |--- P <= 161.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- P >  161.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  731.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  312.40
# |   |   |   |   |   |   |   |   |   |--- C <= 0.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.78
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 589.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  589.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- C >  0.92
# |   |   |   |   |   |   |   |--- A <= 277.51
# |   |   |   |   |   |   |   |   |--- SW <= 0.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SW >  0.04
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  277.51
# |   |   |   |   |   |   |   |   |--- C <= 0.98
# |   |   |   |   |   |   |   |   |   |--- E <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.98
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- A >  891.74
# |   |   |   |   |   |--- C <= 0.81
# |   |   |   |   |   |   |--- EA <= 427.28
# |   |   |   |   |   |   |   |--- C <= 0.60
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- C >  0.60
# |   |   |   |   |   |   |   |   |--- ECA <= 172.46
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  172.46
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- EA >  427.28
# |   |   |   |   |   |   |   |--- C <= 0.80
# |   |   |   |   |   |   |   |   |--- E <= 0.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- E >  0.19
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- SW >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- C >  0.80
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- C >  0.81
# |   |   |   |   |   |   |--- P <= 165.26
# |   |   |   |   |   |   |   |--- SW <= 0.36
# |   |   |   |   |   |   |   |   |--- P <= 138.17
# |   |   |   |   |   |   |   |   |   |--- P <= 136.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- P >  136.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  138.17
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- SW >  0.36
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- P >  165.26
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- C >  0.98
# |   |   |   |   |--- E <= 0.28
# |   |   |   |   |   |--- SW <= 0.49
# |   |   |   |   |   |   |--- E <= 0.25
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- E >  0.25
# |   |   |   |   |   |   |   |--- E <= 0.25
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- E >  0.25
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- SW >  0.49
# |   |   |   |   |   |   |--- SW <= 0.51
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SW >  0.51
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- E >  0.28
# |   |   |   |   |   |--- E <= 0.28
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- E >  0.28
# |   |   |   |   |   |   |--- A <= 1047.20
# |   |   |   |   |   |   |   |--- A <= 351.62
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  351.62
# |   |   |   |   |   |   |   |   |--- P <= 102.73
# |   |   |   |   |   |   |   |   |   |--- A <= 575.65
# |   |   |   |   |   |   |   |   |   |   |--- P <= 80.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- P >  80.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- A >  575.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  102.73
# |   |   |   |   |   |   |   |   |   |--- P <= 153.24
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 402.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  402.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- P >  153.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- A >  1047.20
# |   |   |   |   |   |   |   |--- class: 2
# |--- FL >  1.50
# |   |--- A <= 707.91
# |   |   |--- FL <= 3.50
# |   |   |   |--- A <= 234.48
# |   |   |   |   |--- FA <= 72.57
# |   |   |   |   |   |--- SW <= 0.29
# |   |   |   |   |   |   |--- FA <= 33.93
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FA >  33.93
# |   |   |   |   |   |   |   |--- A <= 30.21
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  30.21
# |   |   |   |   |   |   |   |   |--- A <= 31.19
# |   |   |   |   |   |   |   |   |   |--- E <= 0.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- E >  0.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- A >  31.19
# |   |   |   |   |   |   |   |   |   |--- EA <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- EA >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- SW >  0.29
# |   |   |   |   |   |   |--- E <= 0.81
# |   |   |   |   |   |   |   |--- P <= 27.42
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- P >  27.42
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- E >  0.81
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FA >  72.57
# |   |   |   |   |   |--- E <= 0.39
# |   |   |   |   |   |   |--- FL <= 2.50
# |   |   |   |   |   |   |   |--- ECA <= 107.14
# |   |   |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |   |   |--- C <= 0.73
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.73
# |   |   |   |   |   |   |   |   |   |   |--- A <= 83.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- A >  83.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |   |   |--- E <= 0.36
# |   |   |   |   |   |   |   |   |   |   |--- ECA <= 41.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- ECA >  41.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- E >  0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- ECA >  107.14
# |   |   |   |   |   |   |   |   |--- P <= 63.70
# |   |   |   |   |   |   |   |   |   |--- ECA <= 111.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- ECA >  111.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- P >  63.70
# |   |   |   |   |   |   |   |   |   |--- E <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 145.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  145.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FL >  2.50
# |   |   |   |   |   |   |   |--- FA <= 331.82
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FA >  331.82
# |   |   |   |   |   |   |   |   |--- SW <= 0.42
# |   |   |   |   |   |   |   |   |   |--- E <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SW >  0.42
# |   |   |   |   |   |   |   |   |   |--- EA <= 141.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- EA >  141.15
# |   |   |   |   |   |   |   |   |   |   |--- A <= 227.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- A >  227.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- E >  0.39
# |   |   |   |   |   |   |--- C <= 0.98
# |   |   |   |   |   |   |   |--- SW <= 0.42
# |   |   |   |   |   |   |   |   |--- ECA <= 117.84
# |   |   |   |   |   |   |   |   |   |--- C <= 0.72
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.72
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 121.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FA >  121.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |--- ECA >  117.84
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- SW >  0.42
# |   |   |   |   |   |   |   |   |--- ECA <= 55.73
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 32.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  32.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- SW >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- P <= 31.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- P >  31.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- ECA >  55.73
# |   |   |   |   |   |   |   |   |   |--- E <= 0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- E >  0.42
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- C >  0.98
# |   |   |   |   |   |   |   |--- P <= 54.28
# |   |   |   |   |   |   |   |   |--- FA <= 112.03
# |   |   |   |   |   |   |   |   |   |--- P <= 30.70
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 109.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FA >  109.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- P >  30.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FA >  112.03
# |   |   |   |   |   |   |   |   |   |--- A <= 74.55
# |   |   |   |   |   |   |   |   |   |   |--- A <= 39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- A >  39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- A >  74.55
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 248.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- FA >  248.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- P >  54.28
# |   |   |   |   |   |   |   |   |--- FA <= 370.58
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FA >  370.58
# |   |   |   |   |   |   |   |   |   |--- A <= 193.29
# |   |   |   |   |   |   |   |   |   |   |--- P <= 55.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- P >  55.34
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  193.29
# |   |   |   |   |   |   |   |   |   |   |--- P <= 59.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- P >  59.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |--- A >  234.48
# |   |   |   |   |--- C <= 0.94
# |   |   |   |   |   |--- A <= 563.85
# |   |   |   |   |   |   |--- P <= 102.42
# |   |   |   |   |   |   |   |--- FA <= 979.99
# |   |   |   |   |   |   |   |   |--- FA <= 547.68
# |   |   |   |   |   |   |   |   |   |--- P <= 87.52
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- P >  87.52
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  547.68
# |   |   |   |   |   |   |   |   |   |--- P <= 90.28
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- P >  90.28
# |   |   |   |   |   |   |   |   |   |   |--- A <= 282.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- A >  282.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- FA >  979.99
# |   |   |   |   |   |   |   |   |--- SW <= 0.49
# |   |   |   |   |   |   |   |   |   |--- FA <= 1161.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FA >  1161.34
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 1276.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FA >  1276.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- SW >  0.49
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- P >  102.42
# |   |   |   |   |   |   |   |--- E <= 0.43
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- E >  0.43
# |   |   |   |   |   |   |   |   |--- FA <= 864.62
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  864.62
# |   |   |   |   |   |   |   |   |   |--- C <= 0.76
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.76
# |   |   |   |   |   |   |   |   |   |   |--- P <= 111.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- P >  111.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- A >  563.85
# |   |   |   |   |   |   |--- C <= 0.91
# |   |   |   |   |   |   |   |--- EA <= 526.65
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- EA >  526.65
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- C >  0.91
# |   |   |   |   |   |   |   |--- EA <= 399.86
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- EA >  399.86
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- C >  0.94
# |   |   |   |   |   |--- A <= 443.97
# |   |   |   |   |   |   |--- A <= 421.75
# |   |   |   |   |   |   |   |--- FL <= 2.50
# |   |   |   |   |   |   |   |   |--- EA <= 14.80
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- EA >  14.80
# |   |   |   |   |   |   |   |   |   |--- E <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- E >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- FL >  2.50
# |   |   |   |   |   |   |   |   |--- ECA <= 80.37
# |   |   |   |   |   |   |   |   |   |--- FA <= 1195.85
# |   |   |   |   |   |   |   |   |   |   |--- P <= 69.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- P >  69.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FA >  1195.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ECA >  80.37
# |   |   |   |   |   |   |   |   |   |--- E <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- A >  421.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- A >  443.97
# |   |   |   |   |   |   |--- FA <= 1846.21
# |   |   |   |   |   |   |   |--- A <= 642.66
# |   |   |   |   |   |   |   |   |--- A <= 575.60
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- A >  575.60
# |   |   |   |   |   |   |   |   |   |--- A <= 579.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  579.71
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- A >  642.66
# |   |   |   |   |   |   |   |   |--- FA <= 1289.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  1289.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FA >  1846.21
# |   |   |   |   |   |   |   |--- A <= 618.76
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- A >  618.76
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- FL >  3.50
# |   |   |   |--- SW <= 0.13
# |   |   |   |   |--- P <= 30.57
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- P >  30.57
# |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |--- E <= 0.96
# |   |   |   |   |   |   |   |--- P <= 160.56
# |   |   |   |   |   |   |   |   |--- SW <= 0.13
# |   |   |   |   |   |   |   |   |   |--- E <= 0.65
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- E >  0.65
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- SW >  0.13
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  160.56
# |   |   |   |   |   |   |   |   |--- ECA <= 436.62
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ECA >  436.62
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- E >  0.96
# |   |   |   |   |   |   |   |--- A <= 318.19
# |   |   |   |   |   |   |   |   |--- C <= 0.88
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- A >  318.19
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |--- A <= 609.39
# |   |   |   |   |   |   |   |--- E <= 0.32
# |   |   |   |   |   |   |   |   |--- FA <= 2167.48
# |   |   |   |   |   |   |   |   |   |--- FL <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 1164.59
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- A >  609.39
# |   |   |   |   |   |   |   |--- ECA <= 488.33
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- ECA >  488.33
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- SW >  0.13
# |   |   |   |   |--- SW <= 1.51
# |   |   |   |   |   |--- FL <= 5.50
# |   |   |   |   |   |   |--- A <= 485.73
# |   |   |   |   |   |   |   |--- ECA <= 54.00
# |   |   |   |   |   |   |   |   |--- ECA <= 3.73
# |   |   |   |   |   |   |   |   |   |--- C <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- A <= 130.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- A >  130.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- C >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ECA >  3.73
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- P <= 57.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- P >  57.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- SW >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- ECA >  54.00
# |   |   |   |   |   |   |   |   |--- P <= 43.19
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- P >  43.19
# |   |   |   |   |   |   |   |   |   |--- ECA <= 314.98
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 141.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- EA >  141.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- ECA >  314.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- A >  485.73
# |   |   |   |   |   |   |   |--- SW <= 0.18
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- SW >  0.18
# |   |   |   |   |   |   |   |   |--- P <= 100.89
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- SW >  0.55
# |   |   |   |   |   |   |   |   |   |   |--- P <= 97.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- P >  97.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- P >  100.89
# |   |   |   |   |   |   |   |   |   |--- E <= 0.64
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.64
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 3297.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FA >  3297.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FL >  5.50
# |   |   |   |   |   |   |--- EA <= 495.77
# |   |   |   |   |   |   |   |--- C <= 0.73
# |   |   |   |   |   |   |   |   |--- E <= 0.42
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- E >  0.42
# |   |   |   |   |   |   |   |   |   |--- ECA <= 27.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- ECA >  27.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- C >  0.73
# |   |   |   |   |   |   |   |   |--- EA <= 287.12
# |   |   |   |   |   |   |   |   |   |--- SW <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 349.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FA >  349.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- SW >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- EA >  287.12
# |   |   |   |   |   |   |   |   |   |--- FA <= 3230.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FA >  3230.59
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 288.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  288.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- EA >  495.77
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- SW >  1.51
# |   |   |   |   |   |--- EA <= 64.87
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- EA >  64.87
# |   |   |   |   |   |   |--- class: 1
# |   |--- A >  707.91
# |   |   |--- FL <= 4.50
# |   |   |   |--- FL <= 3.50
# |   |   |   |   |--- C <= 0.94
# |   |   |   |   |   |--- SW <= 0.36
# |   |   |   |   |   |   |--- A <= 837.08
# |   |   |   |   |   |   |   |--- FA <= 2425.75
# |   |   |   |   |   |   |   |   |--- SW <= 0.25
# |   |   |   |   |   |   |   |   |   |--- C <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 2393.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  2393.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SW >  0.25
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FA >  2425.75
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- A >  837.08
# |   |   |   |   |   |   |   |--- C <= 0.46
# |   |   |   |   |   |   |   |   |--- C <= 0.44
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.44
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- C >  0.46
# |   |   |   |   |   |   |   |   |--- E <= 0.34
# |   |   |   |   |   |   |   |   |   |--- E <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- E <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- E >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- E >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- E >  0.34
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- SW >  0.36
# |   |   |   |   |   |   |--- FA <= 2437.08
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FA >  2437.08
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.94
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- FL >  3.50
# |   |   |   |   |--- A <= 959.49
# |   |   |   |   |   |--- SW <= 0.05
# |   |   |   |   |   |   |--- E <= 0.31
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- E >  0.31
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- SW >  0.05
# |   |   |   |   |   |   |--- P <= 115.07
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- P >  115.07
# |   |   |   |   |   |   |   |--- P <= 155.10
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  155.10
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- A >  959.49
# |   |   |   |   |   |--- E <= 0.31
# |   |   |   |   |   |   |--- SW <= 0.04
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SW >  0.04
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- E >  0.31
# |   |   |   |   |   |   |--- P <= 143.24
# |   |   |   |   |   |   |   |--- E <= 0.71
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- E >  0.71
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- P >  143.24
# |   |   |   |   |   |   |   |--- ECA <= 818.92
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- ECA >  818.92
# |   |   |   |   |   |   |   |   |--- ECA <= 822.92
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ECA >  822.92
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- FL >  4.50
# |   |   |   |--- A <= 1960.78
# |   |   |   |   |--- C <= 0.97
# |   |   |   |   |   |--- A <= 1027.18
# |   |   |   |   |   |   |--- SW <= 0.81
# |   |   |   |   |   |   |   |--- P <= 158.21
# |   |   |   |   |   |   |   |   |--- C <= 0.78
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- C >  0.78
# |   |   |   |   |   |   |   |   |   |--- FL <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- FL <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FL >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FL >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 232.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- EA >  232.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- P >  158.21
# |   |   |   |   |   |   |   |   |--- C <= 0.61
# |   |   |   |   |   |   |   |   |   |--- FA <= 4912.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FA >  4912.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- C >  0.61
# |   |   |   |   |   |   |   |   |   |--- FL <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- SW <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- SW >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FL >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SW >  0.81
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- A >  1027.18
# |   |   |   |   |   |   |--- A <= 1043.53
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- A >  1043.53
# |   |   |   |   |   |   |   |--- EA <= 417.27
# |   |   |   |   |   |   |   |   |--- C <= 0.94
# |   |   |   |   |   |   |   |   |   |--- E <= 0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- E >  0.92
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- C >  0.94
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- EA >  417.27
# |   |   |   |   |   |   |   |   |--- EA <= 449.73
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- EA >  449.73
# |   |   |   |   |   |   |   |   |   |--- P <= 254.84
# |   |   |   |   |   |   |   |   |   |   |--- P <= 174.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- P >  174.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- P >  254.84
# |   |   |   |   |   |   |   |   |   |   |--- P <= 320.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- P >  320.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.97
# |   |   |   |   |   |--- SW <= 0.74
# |   |   |   |   |   |   |--- EA <= 1472.89
# |   |   |   |   |   |   |   |--- FA <= 5085.88
# |   |   |   |   |   |   |   |   |--- FA <= 4770.26
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FA >  4770.26
# |   |   |   |   |   |   |   |   |   |--- A <= 839.93
# |   |   |   |   |   |   |   |   |   |   |--- EA <= 300.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- EA >  300.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- A >  839.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FA >  5085.88
# |   |   |   |   |   |   |   |   |--- P <= 110.60
# |   |   |   |   |   |   |   |   |   |--- EA <= 216.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- EA >  216.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- P >  110.60
# |   |   |   |   |   |   |   |   |   |--- FA <= 10983.60
# |   |   |   |   |   |   |   |   |   |   |--- C <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- C >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- FA >  10983.60
# |   |   |   |   |   |   |   |   |   |   |--- FA <= 12753.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FA >  12753.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- EA >  1472.89
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- SW >  0.74
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- A >  1960.78
# |   |   |   |   |--- C <= 0.66
# |   |   |   |   |   |--- FL <= 5.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FL >  5.50
# |   |   |   |   |   |   |--- SW <= 0.02
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SW >  0.02
# |   |   |   |   |   |   |   |--- C <= 0.54
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- C >  0.54
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.66
# |   |   |   |   |   |--- P <= 325.86
# |   |   |   |   |   |   |--- EA <= 1062.10
# |   |   |   |   |   |   |   |--- E <= 0.80
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- E >  0.80
# |   |   |   |   |   |   |   |   |--- EA <= 315.50
# |   |   |   |   |   |   |   |   |   |--- P <= 281.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- P >  281.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- EA >  315.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- EA >  1062.10
# |   |   |   |   |   |   |   |--- SW <= 0.05
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- SW >  0.05
# |   |   |   |   |   |   |   |   |--- FL <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FL >  5.50
# |   |   |   |   |   |   |   |   |   |--- FL <= 9.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FL >  9.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- P >  325.86
# |   |   |   |   |   |   |--- P <= 414.04
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- P >  414.04
# |   |   |   |   |   |   |   |--- EA <= 1345.56
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- EA >  1345.56
# |   |   |   |   |   |   |   |   |--- class: 2

# %%
# A2. COMPUTE ACCURACY BASED ON TRAINING DATA SIZE
# Define the proportions for training data
train_proportions = np.arange(0.01, 0.99, 0.01)

# Lists to store proportions and corresponding accuracies
proportions_list = []
accuracies_list = []

# Loop over each training proportion
for proportion in train_proportions:
    # Set a random seed for reproducibility
    np.random.seed(45)

    # Create a boolean mask for selecting the proportion of the data for training
    mask = np.random.rand(len(building_res)) < proportion

    # Split the data into training and testing sets
    data_train = building_res[mask]
    data_test = building_res[~mask]

    # Initialize the Decision Tree Classifier
    clf = DecisionTreeClassifier()

    # Separate the target variable and features for the training set
    X_train = data_train.drop(columns=['type'])
    y_train = data_train['type']

    # Train the classifier
    clf.fit(X_train, y_train)

    # Separate the features and target variable for the test set
    X_test = data_test.drop(columns=['type'])
    y_test = data_test['type']

    # Make predictions on the test set
    y_pred = clf.predict(X_test)

    # Calculate the accuracy
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy on test data (proportion {proportion}): {accuracy:.2f}")

    # Store the proportion and accuracy
    proportions_list.append(proportion)
    accuracies_list.append(accuracy)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(proportions_list, accuracies_list, marker='o')
plt.title('Accuracy vs Training Data Proportion')
plt.xlabel('Training Data Proportion')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# Accuracy on test data (proportion 0.01): 0.68
# Accuracy on test data (proportion 0.02): 0.74
# Accuracy on test data (proportion 0.03): 0.74
# Accuracy on test data (proportion 0.04): 0.74
# Accuracy on test data (proportion 0.05): 0.74
# Accuracy on test data (proportion 0.060000000000000005): 0.74
# Accuracy on test data (proportion 0.06999999999999999): 0.75
# Accuracy on test data (proportion 0.08): 0.75
# Accuracy on test data (proportion 0.09): 0.75
# Accuracy on test data (proportion 0.09999999999999999): 0.76
# Accuracy on test data (proportion 0.11): 0.75
# Accuracy on test data (proportion 0.12): 0.76
# Accuracy on test data (proportion 0.13): 0.76
# Accuracy on test data (proportion 0.14): 0.76
# Accuracy on test data (proportion 0.15000000000000002): 0.76
# Accuracy on test data (proportion 0.16): 0.75
# Accuracy on test data (proportion 0.17): 0.75
# Accuracy on test data (proportion 0.18000000000000002): 0.76
# Accuracy on test data (proportion 0.19): 0.75
# Accuracy on test data (proportion 0.2): 0.75
# Accuracy on test data (proportion 0.21000000000000002): 0.76
# Accuracy on test data (proportion 0.22): 0.75
# Accuracy on test data (proportion 0.23): 0.75
# Accuracy on test data (proportion 0.24000000000000002): 0.75
# Accuracy on test data (proportion 0.25): 0.76
# Accuracy on test data (proportion 0.26): 0.76
# Accuracy on test data (proportion 0.27): 0.76
# Accuracy on test data (proportion 0.28): 0.76
# Accuracy on test data (proportion 0.29000000000000004): 0.75
# Accuracy on test data (proportion 0.3): 0.75
# Accuracy on test data (proportion 0.31): 0.76
# Accuracy on test data (proportion 0.32): 0.76
# Accuracy on test data (proportion 0.33): 0.76
# Accuracy on test data (proportion 0.34): 0.76
# Accuracy on test data (proportion 0.35000000000000003): 0.75
# Accuracy on test data (proportion 0.36000000000000004): 0.76
# Accuracy on test data (proportion 0.37): 0.77
# Accuracy on test data (proportion 0.38): 0.76
# Accuracy on test data (proportion 0.39): 0.77
# Accuracy on test data (proportion 0.4): 0.77
# Accuracy on test data (proportion 0.41000000000000003): 0.77
# Accuracy on test data (proportion 0.42000000000000004): 0.77
# Accuracy on test data (proportion 0.43): 0.78
# Accuracy on test data (proportion 0.44): 0.76
# Accuracy on test data (proportion 0.45): 0.77
# Accuracy on test data (proportion 0.46): 0.77
# Accuracy on test data (proportion 0.47000000000000003): 0.77
# Accuracy on test data (proportion 0.48000000000000004): 0.77
# Accuracy on test data (proportion 0.49): 0.78
# Accuracy on test data (proportion 0.5): 0.77
# Accuracy on test data (proportion 0.51): 0.77
# Accuracy on test data (proportion 0.52): 0.77
# Accuracy on test data (proportion 0.53): 0.77
# Accuracy on test data (proportion 0.54): 0.78
# Accuracy on test data (proportion 0.55): 0.77
# Accuracy on test data (proportion 0.56): 0.77
# Accuracy on test data (proportion 0.5700000000000001): 0.76
# Accuracy on test data (proportion 0.5800000000000001): 0.77
# Accuracy on test data (proportion 0.59): 0.77
# Accuracy on test data (proportion 0.6): 0.77
# Accuracy on test data (proportion 0.61): 0.77
# Accuracy on test data (proportion 0.62): 0.76
# Accuracy on test data (proportion 0.63): 0.78
# Accuracy on test data (proportion 0.64): 0.78
# Accuracy on test data (proportion 0.65): 0.78
# Accuracy on test data (proportion 0.66): 0.77
# Accuracy on test data (proportion 0.67): 0.77
# Accuracy on test data (proportion 0.68): 0.77
# Accuracy on test data (proportion 0.6900000000000001): 0.77
# Accuracy on test data (proportion 0.7000000000000001): 0.77
# Accuracy on test data (proportion 0.7100000000000001): 0.77
# Accuracy on test data (proportion 0.72): 0.77
# Accuracy on test data (proportion 0.73): 0.77
# Accuracy on test data (proportion 0.74): 0.77
# Accuracy on test data (proportion 0.75): 0.76
# Accuracy on test data (proportion 0.76): 0.77
# Accuracy on test data (proportion 0.77): 0.76
# Accuracy on test data (proportion 0.78): 0.77
# Accuracy on test data (proportion 0.79): 0.76
# Accuracy on test data (proportion 0.8): 0.76
# Accuracy on test data (proportion 0.81): 0.76
# Accuracy on test data (proportion 0.8200000000000001): 0.76
# Accuracy on test data (proportion 0.8300000000000001): 0.75
# Accuracy on test data (proportion 0.8400000000000001): 0.75
# Accuracy on test data (proportion 0.85): 0.76
# Accuracy on test data (proportion 0.86): 0.75
# Accuracy on test data (proportion 0.87): 0.76
# Accuracy on test data (proportion 0.88): 0.75
# Accuracy on test data (proportion 0.89): 0.75
# Accuracy on test data (proportion 0.9): 0.75
# Accuracy on test data (proportion 0.91): 0.76
# Accuracy on test data (proportion 0.92): 0.76
# Accuracy on test data (proportion 0.93): 0.76
# Accuracy on test data (proportion 0.9400000000000001): 0.78
# Accuracy on test data (proportion 0.9500000000000001): 0.77
# Accuracy on test data (proportion 0.9600000000000001): 0.78
# Accuracy on test data (proportion 0.97): 0.79
# Accuracy on test data (proportion 0.98): 0.78
